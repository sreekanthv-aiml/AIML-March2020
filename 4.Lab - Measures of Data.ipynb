# %% [markdown]
# ## Lab Brief - Statistical Learning with Python

# %% [markdown]
# ### Part-1

# %% [markdown]
# ## Measures of Data

# %% [markdown]
# Descriptive Statistcs are measures that summarize important features of data. Producing these descriptive statistics is a common first step to take after cleaning and preparing a dataset for further analysis. Examples are like calculating Mean or Median. In this lab, we will be looking into some of these functions and explore several new ones.

# %% [markdown]
# #### Measures of Central Tendency

# %% [markdown]
# Whenever you measure things of the same kind, a fairly large number of such measurements will tend to cluster around the middle value. Such a value is called a measure of "Central Tendency". The other terms that are used synonymously are "Measures of Location", or "Statistical Averages".

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

mtcars = pd.read_csv('mtcars.csv')

# %%
mtcars
# Out:
#                    name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 24     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 27         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1
# 29         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
#
#     gear  carb
# 0      4     4
# 1      4     4
# 2      4     1
# 3      3     1
# 4      3     2
# 5      3     1
# 6      3     4
# 7      4     2
# 8      4     2
# 9      4     4
# 10     4     4
# 11     3     3
# 12     3     3
# 13     3     3
# 14     3     4
# 15     3     4
# 16     3     4
# 17     4     1
# 18     4     2
# 19     4     1
# 20     3     1
# 21     3     2
# 22     3     2
# 23     3     4
# 24     3     2
# 25     4     1
# 26     5     2
# 27     5     2
# 28     5     4
# 29     5     6
# 30     5     8
# 31     4     2

# %% [markdown]
# ##### Using the mtcars dataset.
#
# For the below set of questions, we will be using the cars data from [Motor Trend Car Road Tests](http://stat.ethz.ch/R-manual/R-devel/library/datasets/html/mtcars.html)
#
# The data was extracted from the 1974 Motor Trend US magazine, and comprises fuel consumption and 10 aspects of automobile design and performance for 32 automobiles (1973–74 models).
#
#
# Details :
#
# A data frame with 32 observations on 11 (numeric) variables.
#
# [, 1] 	mpg 	Miles/(US) gallon
#
# [, 2] 	cyl 	Number of cylinders
#
# [, 3] 	disp 	Displacement (cu.in.)
#
# [, 4] 	hp 	Gross horsepower
#
# [, 5] 	drat 	Rear axle ratio
#
# [, 6] 	wt 	Weight (1000 lbs)
#
# [, 7] 	qsec 	1/4 mile time
#
# [, 8] 	vs 	Engine (0 = V-shaped, 1 = straight)
#
# [, 9] 	am 	Transmission (0 = automatic, 1 = manual)
#
# [,10] 	gear 	Number of forward gears
#
# [,11] 	carb 	Number of carburetors

# %% [markdown]
# #### Explore the data - Setting the index

# %%
mtcars.index = mtcars["name"]
mtcars.head()
# mtcars.mean() #By default this will give the mean of each column
# Out:
#                                 name   mpg  cyl   disp   hp  drat     wt  \
# name
# Mazda RX4                  Mazda RX4  21.0    6  160.0  110  3.90  2.620
# Mazda RX4 Wag          Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875
# Datsun 710                Datsun 710  22.8    4  108.0   93  3.85  2.320
# Hornet 4 Drive        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215
# Hornet Sportabout  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440
#
#                     qsec  vs  am  gear  carb
# name
# Mazda RX4          16.46   0   1     4     4
# Mazda RX4 Wag      17.02   0   1     4     4
# Datsun 710         18.61   1   1     4     1
# Hornet 4 Drive     19.44   1   0     3     1
# Hornet Sportabout  17.02   0   0     3     2

# %% [markdown]
# ### Question 1
#
# What is the first car name given in mtcars?
#
# ** Make use of index which has been set previously **
#
# **Hint**: Use .loc function

# %%
mtcars.iloc[0,0]
# Out:
# 'Mazda RX4'

# %% [markdown]
# ### Question 2
# What is the highest difference between the hp and cyl?
#
# **Hint:** You can use **max()** function to find the difference

# %%
mtcars['Diff_hp_cyl'] = mtcars['hp'] - mtcars['cyl']

# %%
mtcars
# Out:
#                                     name   mpg  cyl   disp   hp  drat     wt  \
# name
# Mazda RX4                      Mazda RX4  21.0    6  160.0  110  3.90  2.620
# Mazda RX4 Wag              Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875
# Datsun 710                    Datsun 710  22.8    4  108.0   93  3.85  2.320
# Hornet 4 Drive            Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215
# Hornet Sportabout      Hornet Sportabout  18.7    8  360.0  175  3.15  3.440
# Valiant                          Valiant  18.1    6  225.0  105  2.76  3.460
# Duster 360                    Duster 360  14.3    8  360.0  245  3.21  3.570
# Merc 240D                      Merc 240D  24.4    4  146.7   62  3.69  3.190
# Merc 230                        Merc 230  22.8    4  140.8   95  3.92  3.150
# Merc 280                        Merc 280  19.2    6  167.6  123  3.92  3.440
# Merc 280C                      Merc 280C  17.8    6  167.6  123  3.92  3.440
# Merc 450SE                    Merc 450SE  16.4    8  275.8  180  3.07  4.070
# Merc 450SL                    Merc 450SL  17.3    8  275.8  180  3.07  3.730
# Merc 450SLC                  Merc 450SLC  15.2    8  275.8  180  3.07  3.780
# Cadillac Fleetwood    Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250
# Lincoln Continental  Lincoln Continental  10.4    8  460.0  215  3.00  5.424
# Chrysler Imperial      Chrysler Imperial  14.7    8  440.0  230  3.23  5.345
# Fiat 128                        Fiat 128  32.4    4   78.7   66  4.08  2.200
# Honda Civic                  Honda Civic  30.4    4   75.7   52  4.93  1.615
# Toyota Corolla            Toyota Corolla  33.9    4   71.1   65  4.22  1.835
# Toyota Corona              Toyota Corona  21.5    4  120.1   97  3.70  2.465
# Dodge Challenger        Dodge Challenger  15.5    8  318.0  150  2.76  3.520
# AMC Javelin                  AMC Javelin  15.2    8  304.0  150  3.15  3.435
# Camaro Z28                    Camaro Z28  13.3    8  350.0  245  3.73  3.840
# Pontiac Firebird        Pontiac Firebird  19.2    8  400.0  175  3.08  3.845
# Fiat X1-9                      Fiat X1-9  27.3    4   79.0   66  4.08  1.935
# Porsche 914-2              Porsche 914-2  26.0    4  120.3   91  4.43  2.140
# Lotus Europa                Lotus Europa  30.4    4   95.1  113  3.77  1.513
# Ford Pantera L            Ford Pantera L  15.8    8  351.0  264  4.22  3.170
# Ferrari Dino                Ferrari Dino  19.7    6  145.0  175  3.62  2.770
# Maserati Bora              Maserati Bora  15.0    8  301.0  335  3.54  3.570
# Volvo 142E                    Volvo 142E  21.4    4  121.0  109  4.11  2.780
#
#                       qsec  vs  am  gear  carb  Diff_hp_cyl     Mean_C  Mean_R
# name
# Mazda RX4            16.46   0   1     4     4          104  36.081667     NaN
# Mazda RX4 Wag        17.02   0   1     4     4          104  36.149583     NaN
# Datsun 710           18.61   1   1     4     1           89  29.048333     NaN
# Hornet 4 Drive       19.44   1   0     3     1          104  44.177917     NaN
# Hornet Sportabout    17.02   0   0     3     2          167  63.109167     NaN
# Valiant              20.22   1   0     3     1           99  40.378333     NaN
# Duster 360           15.84   0   0     3     4          237  74.493333     NaN
# Merc 240D            20.00   1   0     4     2           58  27.415000     NaN
# Merc 230             22.90   1   0     4     2           91  32.547500     NaN
# Merc 280             18.30   1   0     4     4          117  38.955000     NaN
# Merc 280C            18.90   1   0     4     4          117  38.888333     NaN
# Merc 450SE           17.40   0   0     3     3          172  56.895000     NaN
# Merc 450SL           17.60   0   0     3     3          172  56.958333     NaN
# Merc 450SLC          18.00   0   0     3     3          172  56.820833     NaN
# Cadillac Fleetwood   17.98   0   0     3     4          197  77.130000     NaN
# Lincoln Continental  17.82   0   0     3     4          207  77.803667     NaN
# Chrysler Imperial    17.42   0   0     3     4          222  78.974583     NaN
# Fiat 128             19.47   1   1     4     1           62  22.987500     NaN
# Honda Civic          18.52   1   1     4     2           48  20.263750     NaN
# Toyota Corolla       19.90   1   1     4     1           61  22.329583     NaN
# Toyota Corona        20.01   1   0     3     1           93  30.564583     NaN
# Dodge Challenger     16.87   0   0     3     2          142  55.137500     NaN
# AMC Javelin          17.30   0   0     3     2          142  54.007083     NaN
# Camaro Z28           15.41   0   0     3     4          237  73.606667     NaN
# Pontiac Firebird     17.05   0   0     3     2          167  66.514583     NaN
# Fiat X1-9            18.90   1   1     4     1           62  22.517917     NaN
# Porsche 914-2        16.70   0   1     5     2           87  29.964167     NaN
# Lotus Europa         16.90   1   1     5     2          109  31.890250     NaN
# Ford Pantera L       14.50   0   1     5     4          256  77.224167     NaN
# Ferrari Dino         15.50   0   1     5     6          169  45.715833     NaN
# Maserati Bora        14.60   0   1     5     8          327  85.142500     NaN
# Volvo 142E           18.60   1   1     4     2          105  32.824167     NaN

# %%
mtcars.drop(labels=['Mean_C','Mean_R'], axis=1,inplace=True)

# %%
mtcars['Diff_hp_cyl'].max()
# Out:
# 327

# %% [markdown]
# ### Question 3
# What are the cars having highest weight(wt) and lowest weight(wt)?
#
# **Hint:** Use idxmax() and idxmin() to locate the row
#
# Use **.iloc** function to print the  row
#
# **Note:** Both idxmax and idxmin belong to pandas

# %%
mtcars['wt'].idxmax()
# Out:
# 'Lincoln Continental'

# %%
mtcars['wt'].idxmin()
# Out:
# 'Lotus Europa'

# %%
mtcars.loc['Lincoln Continental']
# Out:
# name           Lincoln Continental
# mpg                           10.4
# cyl                              8
# disp                           460
# hp                             215
# drat                             3
# wt                           5.424
# qsec                         17.82
# vs                               0
# am                               0
# gear                             3
# carb                             4
# Diff_hp_cyl                    207
# Name: Lincoln Continental, dtype: object

# %%
mtcars.loc['Lotus Europa']
# Out:
# name           Lotus Europa
# mpg                    30.4
# cyl                       4
# disp                   95.1
# hp                      113
# drat                   3.77
# wt                    1.513
# qsec                   16.9
# vs                        1
# am                        1
# gear                      5
# carb                      2
# Diff_hp_cyl             109
# Name: Lotus Europa, dtype: object

# %% [markdown]
# ### Question 4
#
# Find the mean of each row and each column in the given dataset.
#
# **Hint:** Use .mean() function. To operate on rows use **axis=0**, on columns use **axis=1**

# %%
mtcars.mean(axis=1)
# Out:
# name
# Mazda RX4              36.081667
# Mazda RX4 Wag          36.149583
# Datsun 710             29.048333
# Hornet 4 Drive         44.177917
# Hornet Sportabout      63.109167
# Valiant                40.378333
# Duster 360             74.493333
# Merc 240D              27.415000
# Merc 230               32.547500
# Merc 280               38.955000
# Merc 280C              38.888333
# Merc 450SE             56.895000
# Merc 450SL             56.958333
# Merc 450SLC            56.820833
# Cadillac Fleetwood     77.130000
# Lincoln Continental    77.803667
# Chrysler Imperial      78.974583
# Fiat 128               22.987500
# Honda Civic            20.263750
# Toyota Corolla         22.329583
# Toyota Corona          30.564583
# Dodge Challenger       55.137500
# AMC Javelin            54.007083
# Camaro Z28             73.606667
# Pontiac Firebird       66.514583
# Fiat X1-9              22.517917
# Porsche 914-2          29.964167
# Lotus Europa           31.890250
# Ford Pantera L         77.224167
# Ferrari Dino           45.715833
# Maserati Bora          85.142500
# Volvo 142E             32.824167
# dtype: float64

# %%
mtcars.mean()
# Out:
# mpg             20.090625
# cyl              6.187500
# disp           230.721875
# hp             146.687500
# drat             3.596563
# wt               3.217250
# qsec            17.848750
# vs               0.437500
# am               0.406250
# gear             3.687500
# carb             2.812500
# Diff_hp_cyl    140.500000
# Mean_C          48.016151
# Mean_R                NaN
# dtype: float64

# %% [markdown]
# ### Question 5
#
# Plot mpg values of mtcards dataframe using matplotlib.
#
# **Hint: Use plt.plot function**

# %%
mtcars
# Out:
#                    name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 24     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 27         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1
# 29         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
#
#     gear  carb
# 0      4     4
# 1      4     4
# 2      4     1
# 3      3     1
# 4      3     2
# 5      3     1
# 6      3     4
# 7      4     2
# 8      4     2
# 9      4     4
# 10     4     4
# 11     3     3
# 12     3     3
# 13     3     3
# 14     3     4
# 15     3     4
# 16     3     4
# 17     4     1
# 18     4     2
# 19     4     1
# 20     3     1
# 21     3     2
# 22     3     2
# 23     3     4
# 24     3     2
# 25     4     1
# 26     5     2
# 27     5     2
# 28     5     4
# 29     5     6
# 30     5     8
# 31     4     2

# %%
mtcars.reset_index(drop = True, inplace=True)
plt.plot(mtcars["hp"])

# %% [markdown]
# ## Part 2

# %% [markdown]
# ## Measures of Dispersion

# %% [markdown]
# Measures of Dispersion (Spread) are statistics that describe how data varies. Measure of dispersion gives us the sense of how much the data tends to diverge from the central tendency.

# %% [markdown]
# ### Question 6
#
# What the range of `mpg` in the given dataset?
#
# **Hint:** Range = max-min

# %%
m_max = mtcars['mpg'].max()

# %%
m_min = mtcars['mpg'].min()

# %%
m_range = m_max - m_min
print (m_range)
# Out:
# 23.5

# %% [markdown]
# ### Question 7
#
# Calculate the 25th quantile (lower quantile)for `mpg` in the given dataset.
#
# **Hint:** Use **.quantile()**

# %%
mtcars['mpg'].quantile(.25)
# Out:
# 15.425

# %% [markdown]
# ### Question 8
#
# Calculate the Inter-Quartile Range(IQR) for `mpg` in the given dataset.

# %% [markdown]
# Interquartile range (IQR) is another common measure of spread. IQR is the distance between the 3rd quartile and the 1st quartile.
#
# **Hint:** IQR = Q3 - Q1

# %%
m_iqr = mtcars['mpg'].quantile(.75) - mtcars['mpg'].quantile(.25)
print (m_iqr)
# Out:
# 7.375

# %% [markdown]
# ### Question 9
#
# Calculate the Variance, Standard Deviation and Median Absolute Deviation for `mpg`.

# %% [markdown]
# Variance and Standard Deviation are two other common measure of dispersion.
#
# **Hint:** Use .var() and .std()

# %% [markdown]
# **Hint:** Median Absolute Deviation - alternative measure of spread based on the median. It is the median of the absolute value of the deviations from the median.

# %%
mtcars['mpg'].var()
# Out:
# 36.32410282258065

# %%
mtcars['mpg'].std()
# Out:
# 6.026948052089105

# %%
mtcars['mpg'].mad()
# Out:
# 4.714453125

# %% [markdown]
# ## Part 3

# %% [markdown]
# ## Probability Distributions

# %% [markdown]
# The probability distribution describes how a random variable is distributed. It tells us which values a variable is most likely to take on and which values are less likely to take on.

# %% [markdown]
# Each value in the given range is equally likely to occur.

# %%
import scipy.stats as stats # Many functions for probability distributions in python are in scipy.stats

# %% [markdown]
# ### Question 10
#
# Generate 1000 datapoints with standard normal distribution with mean 0 and standard deviation 1.

# %% [markdown]
# #### Normal Distribution

# %% [markdown]
# The normal or Gaussian Distribution is a continuos probability distribution given by a symmetric bell shaped curve. It is defined its center(mean) and spread(std).

# %% [markdown]
# The bulk of the observations generated from a normal distribution lie near the mean which lies at the center. About 68% of the data lies within 1 std, 95% lies within 2 stds and 99.7% lies within 3 stds.
#
# **Hint:** You can use **np.random.normal()** function to generate normal distribution

# %%
np.random.normal(0,1,1000)
# Out:
# array([-6.33068811e-01,  3.79095343e-01, -2.97046104e-02, -4.07380594e-01,
#         1.30638476e+00,  7.29557413e-01,  8.31203655e-01,  2.67995016e+00,
#        -1.93001316e-01,  2.14392333e+00, -2.61017875e-02, -7.97562957e-01,
#         3.87434325e-01, -1.29952209e+00, -1.81254062e+00,  1.09824852e+00,
#        -7.13414810e-01,  4.59340270e-02,  1.37697404e+00,  7.69749080e-01,
#        -1.14858240e+00,  5.83291652e-01, -6.35062487e-01,  1.20541620e+00,
#         1.71461457e+00,  1.08123946e+00, -2.71629025e-01,  1.03022408e+00,
#        -6.77571774e-01, -5.17436034e-01,  2.37544591e+00, -3.45255240e-01,
#        -1.48730562e-01,  5.46501354e-01,  1.31970528e-01,  4.56817043e-01,
#        -2.23122742e-01,  2.32432901e+00,  4.76123302e-01, -4.47668127e-01,
#         1.91485309e+00,  1.20949884e+00,  1.92603618e+00, -1.26118306e+00,
#         7.13493695e-01, -3.64863056e-01, -9.18142949e-01,  1.67924264e+00,
#         1.58282940e+00, -7.09870269e-01,  8.16759526e-01,  8.49938662e-01,
#         7.83297472e-01, -1.80254794e-01,  8.77346908e-01,  5.67710506e-02,
#         2.14430835e+00, -1.23966945e+00, -1.07772702e+00,  2.79004649e-01,
#        -6.95388998e-01,  2.24453456e-01, -1.03586757e+00, -4.84874945e-01,
#        -1.05639747e-01,  5.87342876e-01, -3.04022657e-01,  1.62591694e-01,
#        -6.68182802e-01,  6.51309260e-01, -1.53497936e+00, -3.97601235e-01,
#         6.42849217e-02,  1.06727092e+00, -1.70907214e+00, -4.01052519e-01,
#         5.39856230e-02,  2.03800220e+00,  1.52068128e+00, -1.19723137e+00,
#        -4.39457302e-01,  5.73017590e-01,  3.27547682e+00, -6.06480273e-02,
#        -3.77240194e-01, -8.64735879e-01, -4.50803966e-01,  1.13260751e-01,
#        -3.24048768e-01, -1.20696864e+00,  7.39552025e-01,  1.29304574e-01,
#         9.29987740e-01,  8.01959938e-01,  1.82993033e+00,  1.13493215e+00,
#        -2.68623756e-01,  2.67282779e-01, -1.81363509e-02,  6.58377249e-02,
#         1.20788319e-01, -7.62546688e-01, -1.32153707e-02,  4.22249445e-02,
#         4.61251845e-01, -1.80027181e-01,  1.72383058e+00, -1.07237730e+00,
#         1.65340459e+00, -4.04564223e-02,  9.50839362e-02, -1.03391184e+00,
#        -5.55422911e-01,  2.52188519e-01,  6.88154824e-01,  1.17579270e+00,
#        -1.22209894e+00,  1.30148649e+00, -1.74445429e-01,  1.77119968e-01,
#         1.17368707e+00,  4.07390552e-01, -6.18950169e-01,  6.29308928e-01,
#        -1.07029940e+00,  1.34869586e+00,  5.78964192e-01, -8.62670912e-01])

# %% [markdown]
# ## Question 11
#
# Generate binomial distribution data for fair coin flipping of size 100. Assume `0` for head and `1` for tail.
#
# [ **Hint:** For fair coin flip `p=0.5` ]

# %% [markdown]
# #### Binomial Distribution

# %% [markdown]
# It is defined by 2 parameters: the probability of success and the number of trails. It tells about how likely it is possible to get a given number of successes in n trails.

# %%
np.random.binomial(100,.5)
# Out:
# 39

# %% [markdown]
# #### Visualizing Poisson Distribution

# %% [markdown]
# It models the probability of seeing certain number of successes within a time interval.

# %%
poisson_data = stats.poisson.rvs(size=100,mu=10)

pd.DataFrame(poisson_data).hist()

plt.show()
